# %%
import nltk

# %%
nltk.sent_tokenize("I am wordlist")
# Out:
# ['I am wordlist']

# %%
thaigrammar = nltk.CFG.fromstring("""

S -> NP VP

VP -> V | V NP | V NP S | V NP PP ADV

PP -> PREP NP

V -> VERB | LAUX VERB | VERB RAUX | LAUX VERB RAUX

NP -> N | N DET | N CLAS DET | N CLAS VATT | N NUM CLAS DET | N VATT CLAS DET | NP PP | NP CONJ NP 

N -> 'คน' | 'แมว' | 'ลิง' | 'ถนน' | 'ข้าว' | 'ลาย' | 'เขา' | 'หนังสือ' | 'นก' | 'ของ' | 'เพื่อน' | 'ฉัน' | 'มหาวิทยาลัย' | 'หมา' | 'ทอม' | 'ของ' | 'เรา' | 'ประโยชน์' | 'เงิน'

VERB -> 'กิน' | 'นอน' | 'เดิน' | 'เล่น' | 'วิ่ง' | 'ทำ' | 'ซื้อ' | 'พบ' | 'ชอบ' | 'มี' | 'เป็น' | 'อยาก'

ADV -> 'ดี' | 'ชั่ว' | 'ใหญ่' | 'ขาว' | 'ร้อน' | 'เย็น' | 'หอม' | 'หวาน' | 'กลม' | 'แบน' | 'เอง' | 'นี้' | 'นั่น' | 'โน่น' | 'ทั้งนี้' | 'ทั้งนั้น' |  'แน่นอน' | 'เป็น'

PREP -> 'ของ' | 'และ' | 'ที่'

DET -> 'เกือบ' | 'นี้' | 'ทั้ง' | 'อีก' | 'ต่างๆ' | 'กว่า'

CLAS -> 'บาท' |  'ชั่วโมง' | 'สาย' | 'เล่ม'

NUM -> 'หนึ่ง' | 'สอง' | 'สาม' | 'สี่' | 'ห้า' | 'หก' | 'เจ็ด' | 'แปด' | 'เก้า'

LAUX -> 'กำลัง' | 'จะ' | 'ได้' | 'แล้ว' | 'ต้อง' | 'อย่า'  | 'จง' | 'โปรด' | 'ช่วย' | 'ควร' | 'คงจะ' | 'อาจจะ' | 'ค่อย'

RAUX -> 'เป็น' | 'เหมือน' | 'คล้าย' | 'เท่า' | 'คือ' | 'เสมือน' | 'ดุจ' | 'บน' | 'เล่น' | 'ได้'

CONJ -> 'ถึงกับ' | 'เมื่อก่อน' | 'ต่อมา' | 'ทั้งนี้ทั้งนั้น' | 'จึง' | 'หรือ' | 'และ'

VATT -> 'ดี' | 'ยิ่ง' | 'หลัก'

""")

# %%
from nltk.parse.generate import generate 
for sentence in generate(thaigrammar, n=900):
    print(' '.join(sentence))
# Out:
# คน กิน
# คน นอน
# คน เดิน
# คน เล่น
# คน วิ่ง
# คน ทำ
# คน ซื้อ
# คน พบ
# คน ชอบ
# คน มี
# คน เป็น
# คน อยาก
# คน กำลัง กิน
# คน กำลัง นอน
# คน กำลัง เดิน
# คน กำลัง เล่น
# คน กำลัง วิ่ง
# คน กำลัง ทำ
# คน กำลัง ซื้อ
# คน กำลัง พบ
# คน กำลัง ชอบ
# คน กำลัง มี
# คน กำลัง เป็น
# คน กำลัง อยาก
# คน จะ กิน
# คน จะ นอน
# คน จะ เดิน
# คน จะ เล่น
# คน จะ วิ่ง
# คน จะ ทำ
# คน จะ ซื้อ
# คน จะ พบ
# คน จะ ชอบ
# คน จะ มี
# คน จะ เป็น
# คน จะ อยาก
# คน ได้ กิน
# คน ได้ นอน
# คน ได้ เดิน
# คน ได้ เล่น
# คน ได้ วิ่ง
# คน ได้ ทำ
# คน ได้ ซื้อ
# คน ได้ พบ
# คน ได้ ชอบ
# คน ได้ มี
# คน ได้ เป็น
# คน ได้ อยาก
# คน แล้ว กิน
# คน แล้ว นอน
# คน แล้ว เดิน
# คน แล้ว เล่น
# คน แล้ว วิ่ง
# คน แล้ว ทำ
# คน แล้ว ซื้อ
# คน แล้ว พบ
# คน แล้ว ชอบ
# คน แล้ว มี
# คน แล้ว เป็น
# คน แล้ว อยาก
# คน ต้อง กิน
# คน ต้อง นอน
# คน ต้อง เดิน
# คน ต้อง เล่น
# คน ต้อง วิ่ง
# คน ต้อง ทำ
# คน ต้อง ซื้อ
# คน ต้อง พบ
# คน ต้อง ชอบ
# คน ต้อง มี
# คน ต้อง เป็น
# คน ต้อง อยาก
# คน อย่า กิน
# คน อย่า นอน
# คน อย่า เดิน
# คน อย่า เล่น
# คน อย่า วิ่ง
# คน อย่า ทำ
# คน อย่า ซื้อ
# คน อย่า พบ
# คน อย่า ชอบ
# คน อย่า มี
# คน อย่า เป็น
# คน อย่า อยาก
# คน จง กิน
# คน จง นอน
# คน จง เดิน
# คน จง เล่น
# คน จง วิ่ง
# คน จง ทำ
# คน จง ซื้อ
# คน จง พบ
# คน จง ชอบ
# คน จง มี
# คน จง เป็น
# คน จง อยาก
# คน โปรด กิน
# คน โปรด นอน
# คน โปรด เดิน
# คน โปรด เล่น
# คน โปรด วิ่ง
# คน โปรด ทำ
# คน โปรด ซื้อ
# คน โปรด พบ
# คน โปรด ชอบ
# คน โปรด มี
# คน โปรด เป็น
# คน โปรด อยาก
# คน ช่วย กิน
# คน ช่วย นอน
# คน ช่วย เดิน
# คน ช่วย เล่น
# คน ช่วย วิ่ง
# คน ช่วย ทำ
# คน ช่วย ซื้อ
# คน ช่วย พบ
# คน ช่วย ชอบ
# คน ช่วย มี
# คน ช่วย เป็น
# คน ช่วย อยาก
# คน ควร กิน
# คน ควร นอน
# คน ควร เดิน
# คน ควร เล่น
# คน ควร วิ่ง
# คน ควร ทำ
# คน ควร ซื้อ
# คน ควร พบ
# คน ควร ชอบ
# คน ควร มี
# คน ควร เป็น
# คน ควร อยาก
# คน คงจะ กิน
# คน คงจะ นอน
# คน คงจะ เดิน
# คน คงจะ เล่น
# คน คงจะ วิ่ง
# คน คงจะ ทำ
# คน คงจะ ซื้อ
# คน คงจะ พบ
# คน คงจะ ชอบ
# คน คงจะ มี
# คน คงจะ เป็น
# คน คงจะ อยาก
# คน อาจจะ กิน
# คน อาจจะ นอน
# คน อาจจะ เดิน
# คน อาจจะ เล่น
# คน อาจจะ วิ่ง
# คน อาจจะ ทำ
# คน อาจจะ ซื้อ
# คน อาจจะ พบ
# คน อาจจะ ชอบ
# คน อาจจะ มี
# คน อาจจะ เป็น
# คน อาจจะ อยาก
# คน ค่อย กิน
# คน ค่อย นอน
# คน ค่อย เดิน
# คน ค่อย เล่น
# คน ค่อย วิ่ง
# คน ค่อย ทำ
# คน ค่อย ซื้อ
# คน ค่อย พบ
# คน ค่อย ชอบ
# คน ค่อย มี
# คน ค่อย เป็น
# คน ค่อย อยาก
# คน กิน เป็น
# คน กิน เหมือน
# คน กิน คล้าย
# คน กิน เท่า
# คน กิน คือ
# คน กิน เสมือน
# คน กิน ดุจ
# คน กิน บน
# คน กิน เล่น
# คน กิน ได้
# คน นอน เป็น
# คน นอน เหมือน
# คน นอน คล้าย
# คน นอน เท่า
# คน นอน คือ
# คน นอน เสมือน
# คน นอน ดุจ
# คน นอน บน
# คน นอน เล่น
# คน นอน ได้
# คน เดิน เป็น
# คน เดิน เหมือน
# คน เดิน คล้าย
# คน เดิน เท่า
# คน เดิน คือ
# คน เดิน เสมือน
# คน เดิน ดุจ
# คน เดิน บน
# คน เดิน เล่น
# คน เดิน ได้
# คน เล่น เป็น
# คน เล่น เหมือน
# คน เล่น คล้าย
# คน เล่น เท่า
# คน เล่น คือ
# คน เล่น เสมือน
# คน เล่น ดุจ
# คน เล่น บน
# คน เล่น เล่น
# คน เล่น ได้
# คน วิ่ง เป็น
# คน วิ่ง เหมือน
# คน วิ่ง คล้าย
# คน วิ่ง เท่า
# คน วิ่ง คือ
# คน วิ่ง เสมือน
# คน วิ่ง ดุจ
# คน วิ่ง บน
# คน วิ่ง เล่น
# คน วิ่ง ได้
# คน ทำ เป็น
# คน ทำ เหมือน
# คน ทำ คล้าย
# คน ทำ เท่า
# คน ทำ คือ
# คน ทำ เสมือน
# คน ทำ ดุจ
# คน ทำ บน
# คน ทำ เล่น
# คน ทำ ได้
# คน ซื้อ เป็น
# คน ซื้อ เหมือน
# คน ซื้อ คล้าย
# คน ซื้อ เท่า
# คน ซื้อ คือ
# คน ซื้อ เสมือน
# คน ซื้อ ดุจ
# คน ซื้อ บน
# คน ซื้อ เล่น
# คน ซื้อ ได้
# คน พบ เป็น
# คน พบ เหมือน
# คน พบ คล้าย
# คน พบ เท่า
# คน พบ คือ
# คน พบ เสมือน
# คน พบ ดุจ
# คน พบ บน
# คน พบ เล่น
# คน พบ ได้
# คน ชอบ เป็น
# คน ชอบ เหมือน
# คน ชอบ คล้าย
# คน ชอบ เท่า
# คน ชอบ คือ
# คน ชอบ เสมือน
# คน ชอบ ดุจ
# คน ชอบ บน
# คน ชอบ เล่น
# คน ชอบ ได้
# คน มี เป็น
# คน มี เหมือน
# คน มี คล้าย
# คน มี เท่า
# คน มี คือ
# คน มี เสมือน
# คน มี ดุจ
# คน มี บน
# คน มี เล่น
# คน มี ได้
# คน เป็น เป็น
# คน เป็น เหมือน
# คน เป็น คล้าย
# คน เป็น เท่า
# คน เป็น คือ
# คน เป็น เสมือน
# คน เป็น ดุจ
# คน เป็น บน
# คน เป็น เล่น
# คน เป็น ได้
# คน อยาก เป็น
# คน อยาก เหมือน
# คน อยาก คล้าย
# คน อยาก เท่า
# คน อยาก คือ
# คน อยาก เสมือน
# คน อยาก ดุจ
# คน อยาก บน
# คน อยาก เล่น
# คน อยาก ได้
# คน กำลัง กิน เป็น
# คน กำลัง กิน เหมือน
# คน กำลัง กิน คล้าย
# คน กำลัง กิน เท่า
# คน กำลัง กิน คือ
# คน กำลัง กิน เสมือน
# คน กำลัง กิน ดุจ
# คน กำลัง กิน บน
# คน กำลัง กิน เล่น
# คน กำลัง กิน ได้
# คน กำลัง นอน เป็น
# คน กำลัง นอน เหมือน
# คน กำลัง นอน คล้าย
# คน กำลัง นอน เท่า
# คน กำลัง นอน คือ
# คน กำลัง นอน เสมือน
# คน กำลัง นอน ดุจ
# คน กำลัง นอน บน
# คน กำลัง นอน เล่น
# คน กำลัง นอน ได้
# คน กำลัง เดิน เป็น
# คน กำลัง เดิน เหมือน
# คน กำลัง เดิน คล้าย
# คน กำลัง เดิน เท่า
# คน กำลัง เดิน คือ
# คน กำลัง เดิน เสมือน
# คน กำลัง เดิน ดุจ
# คน กำลัง เดิน บน
# คน กำลัง เดิน เล่น
# คน กำลัง เดิน ได้
# คน กำลัง เล่น เป็น
# คน กำลัง เล่น เหมือน
# คน กำลัง เล่น คล้าย
# คน กำลัง เล่น เท่า
# คน กำลัง เล่น คือ
# คน กำลัง เล่น เสมือน
# คน กำลัง เล่น ดุจ
# คน กำลัง เล่น บน
# คน กำลัง เล่น เล่น
# คน กำลัง เล่น ได้
# คน กำลัง วิ่ง เป็น
# คน กำลัง วิ่ง เหมือน
# คน กำลัง วิ่ง คล้าย
# คน กำลัง วิ่ง เท่า
# คน กำลัง วิ่ง คือ
# คน กำลัง วิ่ง เสมือน
# คน กำลัง วิ่ง ดุจ
# คน กำลัง วิ่ง บน
# คน กำลัง วิ่ง เล่น
# คน กำลัง วิ่ง ได้
# คน กำลัง ทำ เป็น
# คน กำลัง ทำ เหมือน
# คน กำลัง ทำ คล้าย
# คน กำลัง ทำ เท่า
# คน กำลัง ทำ คือ
# คน กำลัง ทำ เสมือน
# คน กำลัง ทำ ดุจ
# คน กำลัง ทำ บน
# คน กำลัง ทำ เล่น
# คน กำลัง ทำ ได้
# คน กำลัง ซื้อ เป็น
# คน กำลัง ซื้อ เหมือน
# คน กำลัง ซื้อ คล้าย
# คน กำลัง ซื้อ เท่า
# คน กำลัง ซื้อ คือ
# คน กำลัง ซื้อ เสมือน
# คน กำลัง ซื้อ ดุจ
# คน กำลัง ซื้อ บน
# คน กำลัง ซื้อ เล่น
# คน กำลัง ซื้อ ได้
# คน กำลัง พบ เป็น
# คน กำลัง พบ เหมือน
# คน กำลัง พบ คล้าย
# คน กำลัง พบ เท่า
# คน กำลัง พบ คือ
# คน กำลัง พบ เสมือน
# คน กำลัง พบ ดุจ
# คน กำลัง พบ บน
# คน กำลัง พบ เล่น
# คน กำลัง พบ ได้
# คน กำลัง ชอบ เป็น
# คน กำลัง ชอบ เหมือน
# คน กำลัง ชอบ คล้าย
# คน กำลัง ชอบ เท่า
# คน กำลัง ชอบ คือ
# คน กำลัง ชอบ เสมือน
# คน กำลัง ชอบ ดุจ
# คน กำลัง ชอบ บน
# คน กำลัง ชอบ เล่น
# คน กำลัง ชอบ ได้
# คน กำลัง มี เป็น
# คน กำลัง มี เหมือน
# คน กำลัง มี คล้าย
# คน กำลัง มี เท่า
# คน กำลัง มี คือ
# คน กำลัง มี เสมือน
# คน กำลัง มี ดุจ
# คน กำลัง มี บน
# คน กำลัง มี เล่น
# คน กำลัง มี ได้
# คน กำลัง เป็น เป็น
# คน กำลัง เป็น เหมือน
# คน กำลัง เป็น คล้าย
# คน กำลัง เป็น เท่า
# คน กำลัง เป็น คือ
# คน กำลัง เป็น เสมือน
# คน กำลัง เป็น ดุจ
# คน กำลัง เป็น บน
# คน กำลัง เป็น เล่น
# คน กำลัง เป็น ได้
# คน กำลัง อยาก เป็น
# คน กำลัง อยาก เหมือน
# คน กำลัง อยาก คล้าย
# คน กำลัง อยาก เท่า
# คน กำลัง อยาก คือ
# คน กำลัง อยาก เสมือน
# คน กำลัง อยาก ดุจ
# คน กำลัง อยาก บน
# คน กำลัง อยาก เล่น
# คน กำลัง อยาก ได้
# คน จะ กิน เป็น
# คน จะ กิน เหมือน
# คน จะ กิน คล้าย
# คน จะ กิน เท่า
# คน จะ กิน คือ
# คน จะ กิน เสมือน
# คน จะ กิน ดุจ
# คน จะ กิน บน
# คน จะ กิน เล่น
# คน จะ กิน ได้
# คน จะ นอน เป็น
# คน จะ นอน เหมือน
# คน จะ นอน คล้าย
# คน จะ นอน เท่า
# คน จะ นอน คือ
# คน จะ นอน เสมือน
# คน จะ นอน ดุจ
# คน จะ นอน บน
# คน จะ นอน เล่น
# คน จะ นอน ได้
# คน จะ เดิน เป็น
# คน จะ เดิน เหมือน
# คน จะ เดิน คล้าย
# คน จะ เดิน เท่า
# คน จะ เดิน คือ
# คน จะ เดิน เสมือน
# คน จะ เดิน ดุจ
# คน จะ เดิน บน
# คน จะ เดิน เล่น
# คน จะ เดิน ได้
# คน จะ เล่น เป็น
# คน จะ เล่น เหมือน
# คน จะ เล่น คล้าย
# คน จะ เล่น เท่า
# คน จะ เล่น คือ
# คน จะ เล่น เสมือน
# คน จะ เล่น ดุจ
# คน จะ เล่น บน
# คน จะ เล่น เล่น
# คน จะ เล่น ได้
# คน จะ วิ่ง เป็น
# คน จะ วิ่ง เหมือน
# คน จะ วิ่ง คล้าย
# คน จะ วิ่ง เท่า
# คน จะ วิ่ง คือ
# คน จะ วิ่ง เสมือน
# คน จะ วิ่ง ดุจ
# คน จะ วิ่ง บน
# คน จะ วิ่ง เล่น
# คน จะ วิ่ง ได้
# คน จะ ทำ เป็น
# คน จะ ทำ เหมือน
# คน จะ ทำ คล้าย
# คน จะ ทำ เท่า
# คน จะ ทำ คือ
# คน จะ ทำ เสมือน
# คน จะ ทำ ดุจ
# คน จะ ทำ บน
# คน จะ ทำ เล่น
# คน จะ ทำ ได้
# คน จะ ซื้อ เป็น
# คน จะ ซื้อ เหมือน
# คน จะ ซื้อ คล้าย
# คน จะ ซื้อ เท่า
# คน จะ ซื้อ คือ
# คน จะ ซื้อ เสมือน
# คน จะ ซื้อ ดุจ
# คน จะ ซื้อ บน
# คน จะ ซื้อ เล่น
# คน จะ ซื้อ ได้
# คน จะ พบ เป็น
# คน จะ พบ เหมือน
# คน จะ พบ คล้าย
# คน จะ พบ เท่า
# คน จะ พบ คือ
# คน จะ พบ เสมือน
# คน จะ พบ ดุจ
# คน จะ พบ บน
# คน จะ พบ เล่น
# คน จะ พบ ได้
# คน จะ ชอบ เป็น
# คน จะ ชอบ เหมือน
# คน จะ ชอบ คล้าย
# คน จะ ชอบ เท่า
# คน จะ ชอบ คือ
# คน จะ ชอบ เสมือน
# คน จะ ชอบ ดุจ
# คน จะ ชอบ บน
# คน จะ ชอบ เล่น
# คน จะ ชอบ ได้
# คน จะ มี เป็น
# คน จะ มี เหมือน
# คน จะ มี คล้าย
# คน จะ มี เท่า
# คน จะ มี คือ
# คน จะ มี เสมือน
# คน จะ มี ดุจ
# คน จะ มี บน
# คน จะ มี เล่น
# คน จะ มี ได้
# คน จะ เป็น เป็น
# คน จะ เป็น เหมือน
# คน จะ เป็น คล้าย
# คน จะ เป็น เท่า
# คน จะ เป็น คือ
# คน จะ เป็น เสมือน
# คน จะ เป็น ดุจ
# คน จะ เป็น บน
# คน จะ เป็น เล่น
# คน จะ เป็น ได้
# คน จะ อยาก เป็น
# คน จะ อยาก เหมือน
# คน จะ อยาก คล้าย
# คน จะ อยาก เท่า
# คน จะ อยาก คือ
# คน จะ อยาก เสมือน
# คน จะ อยาก ดุจ
# คน จะ อยาก บน
# คน จะ อยาก เล่น
# คน จะ อยาก ได้
# คน ได้ กิน เป็น
# คน ได้ กิน เหมือน
# คน ได้ กิน คล้าย
# คน ได้ กิน เท่า
# คน ได้ กิน คือ
# คน ได้ กิน เสมือน
# คน ได้ กิน ดุจ
# คน ได้ กิน บน
# คน ได้ กิน เล่น
# คน ได้ กิน ได้
# คน ได้ นอน เป็น
# คน ได้ นอน เหมือน
# คน ได้ นอน คล้าย
# คน ได้ นอน เท่า
# คน ได้ นอน คือ
# คน ได้ นอน เสมือน
# คน ได้ นอน ดุจ
# คน ได้ นอน บน
# คน ได้ นอน เล่น
# คน ได้ นอน ได้
# คน ได้ เดิน เป็น
# คน ได้ เดิน เหมือน
# คน ได้ เดิน คล้าย
# คน ได้ เดิน เท่า
# คน ได้ เดิน คือ
# คน ได้ เดิน เสมือน
# คน ได้ เดิน ดุจ
# คน ได้ เดิน บน
# คน ได้ เดิน เล่น
# คน ได้ เดิน ได้
# คน ได้ เล่น เป็น
# คน ได้ เล่น เหมือน
# คน ได้ เล่น คล้าย
# คน ได้ เล่น เท่า
# คน ได้ เล่น คือ
# คน ได้ เล่น เสมือน
# คน ได้ เล่น ดุจ
# คน ได้ เล่น บน
# คน ได้ เล่น เล่น
# คน ได้ เล่น ได้
# คน ได้ วิ่ง เป็น
# คน ได้ วิ่ง เหมือน
# คน ได้ วิ่ง คล้าย
# คน ได้ วิ่ง เท่า
# คน ได้ วิ่ง คือ
# คน ได้ วิ่ง เสมือน
# คน ได้ วิ่ง ดุจ
# คน ได้ วิ่ง บน
# คน ได้ วิ่ง เล่น
# คน ได้ วิ่ง ได้
# คน ได้ ทำ เป็น
# คน ได้ ทำ เหมือน
# คน ได้ ทำ คล้าย
# คน ได้ ทำ เท่า
# คน ได้ ทำ คือ
# คน ได้ ทำ เสมือน
# คน ได้ ทำ ดุจ
# คน ได้ ทำ บน
# คน ได้ ทำ เล่น
# คน ได้ ทำ ได้
# คน ได้ ซื้อ เป็น
# คน ได้ ซื้อ เหมือน
# คน ได้ ซื้อ คล้าย
# คน ได้ ซื้อ เท่า
# คน ได้ ซื้อ คือ
# คน ได้ ซื้อ เสมือน
# คน ได้ ซื้อ ดุจ
# คน ได้ ซื้อ บน
# คน ได้ ซื้อ เล่น
# คน ได้ ซื้อ ได้
# คน ได้ พบ เป็น
# คน ได้ พบ เหมือน
# คน ได้ พบ คล้าย
# คน ได้ พบ เท่า
# คน ได้ พบ คือ
# คน ได้ พบ เสมือน
# คน ได้ พบ ดุจ
# คน ได้ พบ บน
# คน ได้ พบ เล่น
# คน ได้ พบ ได้
# คน ได้ ชอบ เป็น
# คน ได้ ชอบ เหมือน
# คน ได้ ชอบ คล้าย
# คน ได้ ชอบ เท่า
# คน ได้ ชอบ คือ
# คน ได้ ชอบ เสมือน
# คน ได้ ชอบ ดุจ
# คน ได้ ชอบ บน
# คน ได้ ชอบ เล่น
# คน ได้ ชอบ ได้
# คน ได้ มี เป็น
# คน ได้ มี เหมือน
# คน ได้ มี คล้าย
# คน ได้ มี เท่า
# คน ได้ มี คือ
# คน ได้ มี เสมือน
# คน ได้ มี ดุจ
# คน ได้ มี บน
# คน ได้ มี เล่น
# คน ได้ มี ได้
# คน ได้ เป็น เป็น
# คน ได้ เป็น เหมือน
# คน ได้ เป็น คล้าย
# คน ได้ เป็น เท่า
# คน ได้ เป็น คือ
# คน ได้ เป็น เสมือน
# คน ได้ เป็น ดุจ
# คน ได้ เป็น บน
# คน ได้ เป็น เล่น
# คน ได้ เป็น ได้
# คน ได้ อยาก เป็น
# คน ได้ อยาก เหมือน
# คน ได้ อยาก คล้าย
# คน ได้ อยาก เท่า
# คน ได้ อยาก คือ
# คน ได้ อยาก เสมือน
# คน ได้ อยาก ดุจ
# คน ได้ อยาก บน
# คน ได้ อยาก เล่น
# คน ได้ อยาก ได้
# คน แล้ว กิน เป็น
# คน แล้ว กิน เหมือน
# คน แล้ว กิน คล้าย
# คน แล้ว กิน เท่า
# คน แล้ว กิน คือ
# คน แล้ว กิน เสมือน
# คน แล้ว กิน ดุจ
# คน แล้ว กิน บน
# คน แล้ว กิน เล่น
# คน แล้ว กิน ได้
# คน แล้ว นอน เป็น
# คน แล้ว นอน เหมือน
# คน แล้ว นอน คล้าย
# คน แล้ว นอน เท่า
# คน แล้ว นอน คือ
# คน แล้ว นอน เสมือน
# คน แล้ว นอน ดุจ
# คน แล้ว นอน บน
# คน แล้ว นอน เล่น
# คน แล้ว นอน ได้
# คน แล้ว เดิน เป็น
# คน แล้ว เดิน เหมือน
# คน แล้ว เดิน คล้าย
# คน แล้ว เดิน เท่า
# คน แล้ว เดิน คือ
# คน แล้ว เดิน เสมือน
# คน แล้ว เดิน ดุจ
# คน แล้ว เดิน บน
# คน แล้ว เดิน เล่น
# คน แล้ว เดิน ได้
# คน แล้ว เล่น เป็น
# คน แล้ว เล่น เหมือน
# คน แล้ว เล่น คล้าย
# คน แล้ว เล่น เท่า
# คน แล้ว เล่น คือ
# คน แล้ว เล่น เสมือน
# คน แล้ว เล่น ดุจ
# คน แล้ว เล่น บน
# คน แล้ว เล่น เล่น
# คน แล้ว เล่น ได้
# คน แล้ว วิ่ง เป็น
# คน แล้ว วิ่ง เหมือน
# คน แล้ว วิ่ง คล้าย
# คน แล้ว วิ่ง เท่า
# คน แล้ว วิ่ง คือ
# คน แล้ว วิ่ง เสมือน
# คน แล้ว วิ่ง ดุจ
# คน แล้ว วิ่ง บน
# คน แล้ว วิ่ง เล่น
# คน แล้ว วิ่ง ได้
# คน แล้ว ทำ เป็น
# คน แล้ว ทำ เหมือน
# คน แล้ว ทำ คล้าย
# คน แล้ว ทำ เท่า
# คน แล้ว ทำ คือ
# คน แล้ว ทำ เสมือน
# คน แล้ว ทำ ดุจ
# คน แล้ว ทำ บน
# คน แล้ว ทำ เล่น
# คน แล้ว ทำ ได้
# คน แล้ว ซื้อ เป็น
# คน แล้ว ซื้อ เหมือน
# คน แล้ว ซื้อ คล้าย
# คน แล้ว ซื้อ เท่า
# คน แล้ว ซื้อ คือ
# คน แล้ว ซื้อ เสมือน
# คน แล้ว ซื้อ ดุจ
# คน แล้ว ซื้อ บน
# คน แล้ว ซื้อ เล่น
# คน แล้ว ซื้อ ได้
# คน แล้ว พบ เป็น
# คน แล้ว พบ เหมือน
# คน แล้ว พบ คล้าย
# คน แล้ว พบ เท่า
# คน แล้ว พบ คือ
# คน แล้ว พบ เสมือน
# คน แล้ว พบ ดุจ
# คน แล้ว พบ บน
# คน แล้ว พบ เล่น
# คน แล้ว พบ ได้
# คน แล้ว ชอบ เป็น
# คน แล้ว ชอบ เหมือน
# คน แล้ว ชอบ คล้าย
# คน แล้ว ชอบ เท่า
# คน แล้ว ชอบ คือ
# คน แล้ว ชอบ เสมือน
# คน แล้ว ชอบ ดุจ
# คน แล้ว ชอบ บน
# คน แล้ว ชอบ เล่น
# คน แล้ว ชอบ ได้
# คน แล้ว มี เป็น
# คน แล้ว มี เหมือน
# คน แล้ว มี คล้าย
# คน แล้ว มี เท่า
# คน แล้ว มี คือ
# คน แล้ว มี เสมือน
# คน แล้ว มี ดุจ
# คน แล้ว มี บน
# คน แล้ว มี เล่น
# คน แล้ว มี ได้
# คน แล้ว เป็น เป็น
# คน แล้ว เป็น เหมือน
# คน แล้ว เป็น คล้าย
# คน แล้ว เป็น เท่า
# คน แล้ว เป็น คือ
# คน แล้ว เป็น เสมือน
# คน แล้ว เป็น ดุจ
# คน แล้ว เป็น บน
# คน แล้ว เป็น เล่น
# คน แล้ว เป็น ได้
# คน แล้ว อยาก เป็น
# คน แล้ว อยาก เหมือน
# คน แล้ว อยาก คล้าย
# คน แล้ว อยาก เท่า
# คน แล้ว อยาก คือ
# คน แล้ว อยาก เสมือน
# คน แล้ว อยาก ดุจ
# คน แล้ว อยาก บน
# คน แล้ว อยาก เล่น
# คน แล้ว อยาก ได้
# คน ต้อง กิน เป็น
# คน ต้อง กิน เหมือน
# คน ต้อง กิน คล้าย
# คน ต้อง กิน เท่า
# คน ต้อง กิน คือ
# คน ต้อง กิน เสมือน
# คน ต้อง กิน ดุจ
# คน ต้อง กิน บน
# คน ต้อง กิน เล่น
# คน ต้อง กิน ได้
# คน ต้อง นอน เป็น
# คน ต้อง นอน เหมือน
# คน ต้อง นอน คล้าย
# คน ต้อง นอน เท่า
# คน ต้อง นอน คือ
# คน ต้อง นอน เสมือน
# คน ต้อง นอน ดุจ
# คน ต้อง นอน บน
# คน ต้อง นอน เล่น
# คน ต้อง นอน ได้
# คน ต้อง เดิน เป็น
# คน ต้อง เดิน เหมือน
# คน ต้อง เดิน คล้าย
# คน ต้อง เดิน เท่า
# คน ต้อง เดิน คือ
# คน ต้อง เดิน เสมือน
# คน ต้อง เดิน ดุจ
# คน ต้อง เดิน บน
# คน ต้อง เดิน เล่น
# คน ต้อง เดิน ได้
# คน ต้อง เล่น เป็น
# คน ต้อง เล่น เหมือน
# คน ต้อง เล่น คล้าย
# คน ต้อง เล่น เท่า
# คน ต้อง เล่น คือ
# คน ต้อง เล่น เสมือน
# คน ต้อง เล่น ดุจ
# คน ต้อง เล่น บน
# คน ต้อง เล่น เล่น
# คน ต้อง เล่น ได้
# คน ต้อง วิ่ง เป็น
# คน ต้อง วิ่ง เหมือน
# คน ต้อง วิ่ง คล้าย
# คน ต้อง วิ่ง เท่า
# คน ต้อง วิ่ง คือ
# คน ต้อง วิ่ง เสมือน
# คน ต้อง วิ่ง ดุจ
# คน ต้อง วิ่ง บน
# คน ต้อง วิ่ง เล่น
# คน ต้อง วิ่ง ได้
# คน ต้อง ทำ เป็น
# คน ต้อง ทำ เหมือน
# คน ต้อง ทำ คล้าย
# คน ต้อง ทำ เท่า
# คน ต้อง ทำ คือ
# คน ต้อง ทำ เสมือน
# คน ต้อง ทำ ดุจ
# คน ต้อง ทำ บน
# คน ต้อง ทำ เล่น
# คน ต้อง ทำ ได้
# คน ต้อง ซื้อ เป็น
# คน ต้อง ซื้อ เหมือน
# คน ต้อง ซื้อ คล้าย
# คน ต้อง ซื้อ เท่า
# คน ต้อง ซื้อ คือ
# คน ต้อง ซื้อ เสมือน
# คน ต้อง ซื้อ ดุจ
# คน ต้อง ซื้อ บน
# คน ต้อง ซื้อ เล่น
# คน ต้อง ซื้อ ได้
# คน ต้อง พบ เป็น
# คน ต้อง พบ เหมือน
# คน ต้อง พบ คล้าย
# คน ต้อง พบ เท่า
# คน ต้อง พบ คือ
# คน ต้อง พบ เสมือน
# คน ต้อง พบ ดุจ
# คน ต้อง พบ บน
# คน ต้อง พบ เล่น
# คน ต้อง พบ ได้
# คน ต้อง ชอบ เป็น
# คน ต้อง ชอบ เหมือน
# คน ต้อง ชอบ คล้าย
# คน ต้อง ชอบ เท่า
# คน ต้อง ชอบ คือ
# คน ต้อง ชอบ เสมือน
# คน ต้อง ชอบ ดุจ
# คน ต้อง ชอบ บน
# คน ต้อง ชอบ เล่น
# คน ต้อง ชอบ ได้
# คน ต้อง มี เป็น
# คน ต้อง มี เหมือน
# คน ต้อง มี คล้าย
# คน ต้อง มี เท่า
# คน ต้อง มี คือ
# คน ต้อง มี เสมือน
# คน ต้อง มี ดุจ
# คน ต้อง มี บน
# คน ต้อง มี เล่น
# คน ต้อง มี ได้
# คน ต้อง เป็น เป็น
# คน ต้อง เป็น เหมือน
# คน ต้อง เป็น คล้าย
# คน ต้อง เป็น เท่า
# คน ต้อง เป็น คือ
# คน ต้อง เป็น เสมือน
# คน ต้อง เป็น ดุจ
# คน ต้อง เป็น บน
# คน ต้อง เป็น เล่น
# คน ต้อง เป็น ได้
# คน ต้อง อยาก เป็น
# คน ต้อง อยาก เหมือน
# คน ต้อง อยาก คล้าย
# คน ต้อง อยาก เท่า
# คน ต้อง อยาก คือ
# คน ต้อง อยาก เสมือน
# คน ต้อง อยาก ดุจ
# คน ต้อง อยาก บน
# คน ต้อง อยาก เล่น
# คน ต้อง อยาก ได้
# คน อย่า กิน เป็น
# คน อย่า กิน เหมือน
# คน อย่า กิน คล้าย
# คน อย่า กิน เท่า
# คน อย่า กิน คือ
# คน อย่า กิน เสมือน
# คน อย่า กิน ดุจ
# คน อย่า กิน บน
# คน อย่า กิน เล่น
# คน อย่า กิน ได้
# คน อย่า นอน เป็น
# คน อย่า นอน เหมือน

# %%
rd_parser = nltk.RecursiveDescentParser(thaigrammar) 
sent = 'หนังสือ สาม เล่ม นี้ มี ประโยชน์'.split()
for tree in rd_parser.parse(sent):
    print(tree)
# Out:
# (S
#   (NP (N หนังสือ) (NUM สาม) (CLAS เล่ม) (DET นี้))
#   (VP (V (VERB มี)) (NP (N ประโยชน์))))
